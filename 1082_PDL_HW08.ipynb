# %% [markdown]
# # Homework #8

# %% [raw]
# File Naming Rule: 1082_PDL_HWX_StudentID.ipynb
#              e.g. 1082_PDL_HW01_104123456.ipynb

# %% [raw]
# Due Date: May 14, 12:00 pm. (Hard Dealine)

# %% [markdown]
# How to do it? Uploading your .ipynb file into the corresponding homework in the LMS system. Any delay will not be accepted.

# %% [markdown]
# ### Video Game Sales | Kaggle
# https://www.kaggle.com/gregorut/videogamesales

# %% [markdown]
# This dataset (vgsales.csv) contains sales data from more than 16,500 games.
# Fields include:
# * Rank - Ranking of overall sales
# * Name - The games name
# * Platform - Platform of the games release (i.e. PC,PS4, etc.)
# * Year - Year of the game's release
# * Genre - Genre of the game
# * Publisher - Publisher of the game
# * NA_Sales - Sales in North America (in millions)
# * EU_Sales - Sales in Europe (in millions)
# * JP_Sales - Sales in Japan (in millions)
# * Other_Sales - Sales in the rest of the world (in millions)
# * Global_Sales - Total worldwide sales.

# %% [markdown]
# ##  Question: (10 points)

# %% [markdown]
# ### Creating a histogram to show the global sales (in millions) of three platforms (i.e., PS4, Wii, and X360) from 2006 to 2015.

# %% [markdown]
# # https://holidaybookworm.blogspot.com/2016/09/difference-between-histogram-and-bar.html
# 左：直方圖(Histogram )
#
# 描述的是連續性的數據資料(x-axis: Numerical/Quantitative)
# 資料間隔 Interval（Bin size) 可以隨意調整，而隨意調整並不會打壞想要呈現的數據。只是讓你更容易瀏覽不同分法下，呈現出不同資料樣的樣貌。如上圖Sample of Udacity studenets’ ages，為5歲為一個級距，但可以隨意調整成15歲為一個級距，或者50歲為一個級距來看不同級距資料的變化。Bin size 的概念，可以想成想裝多少個箱子，或者是把什麼東西放到這個箱子內。
# 直方圖的級距有邏輯與順序性，因為是描述連續性的資料，如數字等。
#
#
# 右：柱狀圖(Bar graph)
#
# 描述的是確切的類別(x:axis: Categorical/qualitative)
# 無法調整級距，因為是屬於category類型資料的呈現，如右圖，呈現的是各州學生的分佈。由於是顯示不同的類別的資料，雖然是描述同一件事情（頻率）但Bar的顏色各自代表其類別。
# 級距之間的排序較不嚴謹，可以隨意調整想要排列的順序，如把Europe, North America, Aisa改成Aisa, North America, Europe等。

# %% [markdown]
# ![6B3CE602-AD16-4631-A74F-18571EC3D225.png](attachment:6B3CE602-AD16-4631-A74F-18571EC3D225.png)

# %%
import numpy as np
import pandas as pd

# %%
sale = pd.read_csv('vgsales.csv')
sale
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.ticker as ticker#為了降低x軸密集度

# %%
sale['total'] = sale['NA_Sales']+sale['EU_Sales']+sale['JP_Sales']+sale['Other_Sales']#等同global,若沒給可以這樣用
sale
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
row=(sale['Year']>=2006)&(sale['Year']<=2015)
sale[row]
# Out:
#         Rank                                               Name Platform  \
# 0          1                                         Wii Sports      Wii
# 2          3                                     Mario Kart Wii      Wii
# 3          4                                  Wii Sports Resort      Wii
# 6          7                              New Super Mario Bros.       DS
# 7          8                                           Wii Play      Wii
# ...      ...                                                ...      ...
# 16588  16591                                   Mega Brain Boost       DS
# 16590  16593  Eiyuu Densetsu: Sora no Kiseki Material Collec...      PSP
# 16592  16595                                           Plushees       DS
# 16595  16598   SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                         Know How 2       DS
#
#          Year         Genre              Publisher  NA_Sales  EU_Sales  \
# ...

# %%
import numpy as np
wii=np.zeros(10)
x360=np.zeros(10)
ps4=np.zeros(10)
for i in range(0,len(sale)):
    if (sale['Year'][i]>=2006)&(sale['Year'][i]<=2015):
        if sale['Platform'][i]=='Wii':
            wii[int(sale['Year'][i]-2006)]=wii[int(sale['Year'][i]-2006)]+sale['total'][i]
        elif sale['Platform'][i]=='X360':
            x360[int(sale['Year'][i]-2006)]=x360[int(sale['Year'][i]-2006)]+sale['total'][i]
        elif sale['Platform'][i]=='PS4':
            ps4[int(sale['Year'][i]-2006)]= ps4[int(sale['Year'][i]-2006)]+sale['total'][i]

# %%
year=[]
for i in range(0,10):
    year.append(2006+i)
year
# Out:
# [2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015]

# %%
after=sale[row].groupby(["Year","Platform"]).sum()
after[0:10]
# Out:
#                     Rank  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Year   Platform
# 2006.0 DS        1887445     50.63     23.53     38.56         8.28
#        GBA        452358      2.70      0.98      1.51         0.09
#        GC         318654      8.51      2.28      0.21         0.26
#        PC         724884      0.60      1.92      0.00         0.39
#        PS2       2459627     49.93     21.61     17.64        14.24
#        PS3        171350      8.83      7.47      1.07         3.69
#        PSP       1892673     27.99     14.24      4.39         9.14
#        Wii        311347     71.30     43.84      9.15        13.56
#        X360       678478     35.16     11.12      1.20         4.46
#        XB         666777      7.47      2.25      0.00         0.32
#
#                  Global_Sales   total
# Year   Platform
# 2006.0 DS              121.15  121.00
#        GBA               5.35    5.28
#        GC               11.29   11.26
# ...

# %% [raw]
# after=after.drop(after.columns[2:4],axis=0)
# after

# %%
#似乎只能這樣抓非之前groupby的column :( ，所以就沒用直接取pandas，改一個一個抓值出來
after[11:12]['Rank']
# Out:
# Year    Platform
# 2007.0  DS          3480242
# Name: Rank, dtype: int64

# %%
#以下為check答案是否正確
ps4
# Out:
# array([  0.  ,   0.  ,   0.  ,   0.  ,   0.  ,   0.  ,   0.  ,  24.76,
#         98.83, 115.24])

# %%
x360
# Out:
# array([ 51.94,  95.79, 135.66, 120.92, 170.95, 145.08, 100.82,  89.56,
#         36.43,  13.02])

# %%
wii
# Out:
# array([137.85, 154.77, 174.07, 210.26, 131.78,  62.32,  22.78,   9.38,
#          4.43,   1.56])

# %%
#參考:https://ithelp.ithome.com.tw/articles/10211488
col_count = 3                  # 由於有3個月，設定類別基數為3
bar_width = 0.2                # 設定長條圖每個長條寬度
index = np.arange(len(year))   # 依據10個類別(10年)設定索引值，便於後續長條圖的位置設定,index=array([0, 1, 2, 3....,9,10])

fig = plt.figure()
fig.set_size_inches(18.5, 10.5)

# 設定bar的圖型
A = plt.bar(index,         # 索引值代表A肇事原因的長條位置，如index=[0,1,2]，分別在3個月的第一個位置
           ps4,              # 設定長條圖的資料 
           bar_width,      # 設定長條寬度
           alpha=.6,       # 設定透明度
           label="PS4")# 設定標籤 
B = plt.bar(index+0.2,     # 索引值為A的索引值+0.2(長條寬度)，顯示於A長條的旁邊一個長條寬度的位置
            wii,
            bar_width,
            alpha=.6,
            label="Wii") 
C = plt.bar(index+0.4,
            x360,
            bar_width,
            alpha=.6,
            label="X360")


# 使得每個長條圖上顯示資料標籤，詳見：[https://stackoverflow.com/questions/40489821/how-to-write-text-above-the-bars-on-a-bar-plot-python](http://)
def createLabels(data):                   # 自定義函數，為引用plusone團隊
    for item in data:
        height = item.get_height()
        plt.text(
            item.get_x()+item.get_width()/2., 
            height*1.05, 
            '%d' % int(height),
            ha = "center",
            va = "bottom",
        )
createLabels(A)
createLabels(B)
createLabels(C)

# 定義標籤
plt.ylabel("global sales (in millions)")          # 設定y軸標題 
plt.xlabel("year")            # 設定x軸標題
plt.title("histogram of selling(2006-2015)", {'fontsize' : 17})  # 設定標題、文字大小
plt.xticks(index+ .3 / 2 ,("2006", "2007", "2008","2009","2010","2011","2012","2013","2014","2015"))  
#.xticks為x軸文字(為了置中所以+0.3/2)
plt.ylim(0, 250)                 # 設定y軸範圍
plt.legend(prop = {'size':20})    # 設定圖例及其大小
plt.grid(True)                   # 顯示格線

# %%
# 儲存圖檔
plt.savefig("histogram of selling(2006-2015).jpg",   # 儲存圖檔
            bbox_inches='tight',               # 去除座標軸占用的空間
            pad_inches=0.0)                    # 去除所有白邊
plt.close()      # 關閉圖表
